# %%
import json

python_dict = {
    "name": "Alice",
    "age": 30,
    "isStudent": False,
    "courses": ["Math", "Science"]
}
file_name = 'my_data.json'

# Save the dictionary to a JSON file
with open(file_name, 'w') as f:
    json.dump(python_dict, f, indent=4)
print(f"Python dictionary saved to '{file_name}'")

# Load the dictionary from the JSON file
with open(file_name, 'r') as f:
    loaded_from_file = json.load(f)
print(f"Python dictionary loaded from '{file_name}': {loaded_from_file}")
# Out:
# Python dictionary saved to 'my_data.json'
# Python dictionary loaded from 'my_data.json': {'name': 'Alice', 'age': 30, 'isStudent': False, 'courses': ['Math', 'Science']}
