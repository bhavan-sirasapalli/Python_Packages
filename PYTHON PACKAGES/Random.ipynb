# %%
import random

print(f"Random float between 0 and 1: {random.random()}")


print(f"Random integer between 1 and 10: {random.randint(1, 10)}")

my_list = ['apple', 'banana', 'cherry', 'date']
print(f"Random element from list: {random.choice(my_list)}")

my_string = "Python"
print(f"Random character from string: {random.choice(my_string)}")
# Out:
# Random float between 0 and 1: 0.7457386905180147
# Random integer between 1 and 10: 5
# Random element from list: apple
# Random character from string: y
