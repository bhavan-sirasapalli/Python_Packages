# %%
import pandas as pd

data = {
    'Category': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'B'],
    'Value': [10, 15, 12, 20, 18, 11, 22, 16]
}
df = pd.DataFrame(data)

print("Original DataFrame:")
display(df)
# Out:
# Original DataFrame:
#   Category  Value
# 0        A     10
# 1        B     15
# 2        A     12
# 3        C     20
# 4        B     18
# 5        A     11
# 6        C     22
# 7        B     16
